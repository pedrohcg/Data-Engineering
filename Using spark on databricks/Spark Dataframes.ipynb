# %%
df = spark.read.csv('dbfs:/public/retail_db/orders/part-00000', schema='order_id INT, order_date DATE, order_customer_id INT, order_status STRING')

# %%
display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_date</th><th>order_customer_id</th><th>order_status</th></tr></thead><tbody><tr><td>1</td><td>2013-07-25</td><td>11599</td><td>CLOSED</td></tr><tr><td>2</td><td>2013-07-25</td><td>256</td><td>PENDING_PAYMENT</td></tr><tr><td>3</td><td>2013-07-25</td><td>12111</td><td>COMPLETE</td></tr><tr><td>4</td><td>2013-07-25</td><td>8827</td><td>CLOSED</td></tr><tr><td>5</td><td>2013-07-25</td><td>11318</td><td>COMPLETE</td></tr><tr><td>6</td><td>2013-07-25</td><td>7130</td><td>COMPLETE</td></tr><tr><td>7</td><td>2013-07-25</td><td>4530</td><td>COMPLETE</td></tr><tr><td>8</td><td>2013-07-25</td><td>2911</td><td>PROCESSING</td></tr><tr><td>9</td><td>2013-07-25</td><td>5657</td><td>PENDING_PAYMENT</td></tr><tr><td>10</td><td>2013-07-25</td><td>5648</td><td>PENDING_PAYMENT</td></tr></tbody></table></div>

# %%
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/public/retail_db/orders/_SUCCESS</td><td>_SUCCESS</td><td>0</td><td>1695941472313</td></tr><tr><td>dbfs:/public/retail_db/orders/_committed_9103897215061897648</td><td>_committed_9103897215061897648</td><td>288</td><td>1695941471769</td></tr><tr><td>dbfs:/public/retail_db/orders/_started_9103897215061897648</td><td>_started_9103897215061897648</td><td>0</td><td>1695941468365</td></tr><tr><td>dbfs:/public/retail_db/orders/part-00000</td><td>part-00000</td><td>2999944</td><td>1695942912060</td></tr></tbody></table></div>

# %%
sales = [[1000, 12.5], [1200, 10], [750, 20]]

# %%
import pandas as pd

# %%
sales_df = pd.DataFrame(sales, columns=['sale_amount', 'comission_pct'])

# %%
sales_df
# Out:
#    sale_amount  comission_pct
# 0         1000           12.5
# 1         1200           10.0
# 2          750           20.0

# %%
sales_df.apply(lambda rec: ((rec['sale_amount'] * rec['comission_pct'])/ 100), axis=1)
# Out:
# 0    125.0
# 1    120.0
# 2    150.0
# dtype: float64

# %%
df = spark.read.csv('dbfs:/public/retail_db/orders/part-00000', schema='order_id INT, order_date DATE, order_customer_id INT, order_status STRING')

# %%
df.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- order_customer_id: integer (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
df.columns
# Out:
# ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %%
display(df.select('order_date' , 'order_status').distinct().orderBy('order_date', 'order_status').count())
# Out:
# 3203

# %%
display(df.drop('order_customer_id').limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order
# %%
display(df.drop('order_customer_id').withColumn('order_month', cast('int', date_format('order_date', 'yyyyMM'))).limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_date</th><th>order_status</th><th>order_month</th></tr></thead><tbody><tr><td>1</td><td>2013-07-25</td><td>CLOSED</td><td>201307</td></tr><tr><td>2</td><td>2013-07-25</td><td>PENDING_PAYMENT</td><td>201307</td></tr><tr><td>3</td><td>2013-07-25</td><td>COMPLETE</td><td>201307</td></tr><tr><td>4</td><td>2013-07-25</td><td>CLOSED</td><td>201307</td></tr><tr><td>5</td><td>2013-07-25</td><td>COMPLETE</td><td>201307</td></tr><tr><td>6</td><td>2013-07-25</td><td>COMPLETE</td><td>201307</td></tr><tr><td>7</td><td>2013-07-25</td><td>COMPLETE</td><td>201307</td></tr><tr><td>8</td><td>2013-07-25</td><td>PROCESSING</td><td>201307</td></tr><tr><td>9</td><td>2013-07-25</td><td>PENDING_PAYMENT</td><td>201307</td></tr><tr><td>10</td><td>2013-07-25</td><td>PENDING_PAYMENT</td><td>201307</td></tr></tbody></table></div>

# %%
df.write.format('delta').save('dbfs:/public/retail_db_delta/orders')

# %%
# %fs ls dbfs:/public/retail_db_delta/orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/public/retail_db_delta/orders/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1695945375104</td></tr><tr><td>dbfs:/public/retail_db_delta/orders/part-00000-0b1d4d44-0165-4eac-9271-026a5c354797-c000.snappy.parquet</td><td>part-00000-0b1d4d44-0165-4eac-9271-026a5c354797-c000.snappy.parquet</td><td>488399</td><td>1695945376269</td></tr></tbody></table></div>

# %%
display(spark.read.format('delta').load('dbfs:/public/retail_db_delta/orders').limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_date</th><th>order_customer_id</th><th>order_status</th></tr></thead><tbody><tr><td>1</td><td>2013-07-25</td><td>11599</td><td>CLOSED</td></tr><tr><td>2</td><td>2013-07-25</td><td>256</td><td>PENDING_PAYMENT</td></tr><tr><td>3</td><td>2013-07-25</td><td>12111</td><td>COMPLETE</td></tr><tr><td>4</td><td>2013-07-25</td><td>8827</td><td>CLOSED</td></tr><tr><td>5</td><td>2013-07-25</td><td>11318</td><td>COMPLETE</td></tr><tr><td>6</td><td>2013-07-25</td><td>7130</td><td>COMPLETE</td></tr><tr><td>7</td><td>2013-07-25</td><td>4530</td><td>COMPLETE</td></tr><tr><td>8</td><td>2013-07-25</td><td>2911</td><td>PROCESSING</td></tr><tr><td>9</td><td>2013-07-25</td><td>5657</td><td>PENDING_PAYMENT</td></tr><tr><td>10</td><td>2013-07-25</td><td>5648</td><td>PENDING_PAYMENT</td></tr></tbody></table></div>
